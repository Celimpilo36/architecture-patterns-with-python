# %% [markdown]
# # Architecture Patterns with Python
#
# ## Chapter 0: Introduction & Setup
#
# **Book**: Architecture Patterns with Python by Harry Percival & Bob Gregory
#
# **My Goal**: Understand and implement Clean Architecture, DDD, and TDD in real Python projects.

# %% [markdown]
# ## Key Concepts Learned
#
# ### 1. Clean Architecture
# - Separation of concerns
# - Dependency Rule: Inner layers should not depend on outer layers
# - Domain → Application → Adapters → Frameworks
#
# ### 2. Why this matters
# - Testable code
# - Maintainable code
# - Framework independent

# %%
# Project Structure Overview
print("""
src/
├── domain/           # Business logic (independent)
├── service_layer/    # Use cases
├── adapters/         # Technical details
├── entrypoints/      # Delivery mechanism (FastAPI)
""")
# Out:
# src/
# ├── domain/           # Business logic (independent)
# ├── service_layer/    # Use cases
# ├── adapters/         # Technical details
# ├── entrypoints/      # Delivery mechanism (FastAPI)

# %% [markdown]
# ## My Current Progress
# - [x] Project setup with proper folder structure
# - [x] FastAPI basic endpoint
# - [x] Basic tests (unittest)
# - [x] Repository pattern
# - [] Unit of Work (not started)
#
# **Date**: 30 May 2026
